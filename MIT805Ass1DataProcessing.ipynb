# %%
import pandas as pd
from google.colab import drive

# %%
#Mount google drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#Loading datasets into pandas 
articles_df = pd.read_csv(r'/content/gdrive/MyDrive/MIT805/Dataset/h&m/articles.csv')
customers_df = pd.read_csv(r'/content/gdrive/MyDrive/MIT805/Dataset/h&m/customers.csv')
transactions_df = pd.read_csv(r'/content/gdrive/MyDrive/MIT805/Dataset/h&m/transactions_train.csv')

# %%
#Print unique column values in data frame
def print_unique_col_values(df):
  for column in df:
    print(f'{column} : {df[column].unique()}')

# %%
transactions_df.head()
# Out:
#         t_dat                                        customer_id  article_id  \
# 0  2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...   663713001
# 1  2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...   541518023
# 2  2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...   505221004
# 3  2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...   685687003
# 4  2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...   685687004
#
#       price  sales_channel_id
# 0  0.050831                 2
# 1  0.030492                 2
# 2  0.015237                 2
# 3  0.016932                 2
# 4  0.016932                 2

# %%
transactions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31788324 entries, 0 to 31788323
# Data columns (total 5 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   t_dat             object
#  1   customer_id       object
#  2   article_id        int64
#  3   price             float64
#  4   sales_channel_id  int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 1.2+ GB

# %%
transactions_df.describe()
# Out:
#          article_id         price  sales_channel_id
# count  3.178832e+07  3.178832e+07      3.178832e+07
# mean   6.962272e+08  2.782927e-02      1.704028e+00
# std    1.334480e+08  1.918113e-02      4.564786e-01
# min    1.087750e+08  1.694915e-05      1.000000e+00
# 25%    6.328030e+08  1.581356e-02      1.000000e+00
# 50%    7.145820e+08  2.540678e-02      2.000000e+00
# 75%    7.865240e+08  3.388136e-02      2.000000e+00
# max    9.562170e+08  5.915254e-01      2.000000e+00

# %%
print_unique_col_values(transactions_df)
# Out:
# t_dat : ['2018-09-20' '2018-09-21' '2018-09-22' '2018-09-23' '2018-09-24'
#  '2018-09-25' '2018-09-26' '2018-09-27' '2018-09-28' '2018-09-29'
#  '2018-09-30' '2018-10-01' '2018-10-02' '2018-10-03' '2018-10-04'
#  '2018-10-05' '2018-10-06' '2018-10-07' '2018-10-08' '2018-10-09'
#  '2018-10-10' '2018-10-11' '2018-10-12' '2018-10-13' '2018-10-14'
#  '2018-10-15' '2018-10-16' '2018-10-17' '2018-10-18' '2018-10-19'
#  '2018-10-20' '2018-10-21' '2018-10-22' '2018-10-23' '2018-10-24'
#  '2018-10-25' '2018-10-26' '2018-10-27' '2018-10-28' '2018-10-29'
#  '2018-10-30' '2018-10-31' '2018-11-01' '2018-11-02' '2018-11-03'
#  '2018-11-04' '2018-11-05' '2018-11-06' '2018-11-07' '2018-11-08'
#  '2018-11-09' '2018-11-10' '2018-11-11' '2018-11-12' '2018-11-13'
#  '2018-11-14' '2018-11-15' '2018-11-16' '2018-11-17' '2018-11-18'
#  '2018-11-19' '2018-11-20' '2018-11-21' '2018-11-22' '2018-11-23'
#  '2018-11-24' '2018-11-25' '2018-11-26' '2018-11-27' '2018-11-28'
# ...

# %%
customers_df.head()
# Out:
#                                          customer_id   FN  Active  \
# 0  00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...  NaN     NaN
# 1  0000423b00ade91418cceaf3b26c6af3dd342b51fd051e...  NaN     NaN
# 2  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...  NaN     NaN
# 3  00005ca1c9ed5f5146b52ac8639a40ca9d57aeff4d1bd2...  NaN     NaN
# 4  00006413d8573cd20ed7128e53b7b13819fe5cfc2d801f...  1.0     1.0
#
#   club_member_status fashion_news_frequency   age  \
# 0             ACTIVE                   NONE  49.0
# 1             ACTIVE                   NONE  25.0
# 2             ACTIVE                   NONE  24.0
# 3             ACTIVE                   NONE  54.0
# 4             ACTIVE              Regularly  52.0
#
#                                          postal_code
# 0  52043ee2162cf5aa7ee79974281641c6f11a68d276429a...
# 1  2973abc54daa8a5f8ccfe9362140c63247c5eee03f1d93...
# 2  64f17e6a330a85798e4998f62d0930d14db8db1c054af6...
# ...

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1371980 entries, 0 to 1371979
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   customer_id             1371980 non-null  object
#  1   FN                      476930 non-null   float64
#  2   Active                  464404 non-null   float64
#  3   club_member_status      1365918 non-null  object
#  4   fashion_news_frequency  1355971 non-null  object
#  5   age                     1356119 non-null  float64
#  6   postal_code             1371980 non-null  object
# dtypes: float64(3), object(4)
# memory usage: 73.3+ MB

# %%
#Dropping null values
customers_df =customers_df.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

# %%
customers_df.head()
# Out:
#                                           customer_id   FN  Active  \
# 4   00006413d8573cd20ed7128e53b7b13819fe5cfc2d801f...  1.0     1.0
# 7   00007d2de826758b65a93dd24ce629ed66842531df6699...  1.0     1.0
# 13  00009d946eec3ea54add5ba56d5210ea898def4b46c685...  1.0     1.0
# 14  0000ae1bbb25e04bdc7e35f718e852adfb3fbb72ef38b3...  1.0     1.0
# 15  0000b2f1829e23b24feec422ef13df3ccedaedc85368e6...  1.0     1.0
#
#    club_member_status fashion_news_frequency   age  \
# 4              ACTIVE              Regularly  52.0
# 7              ACTIVE              Regularly  32.0
# 13             ACTIVE              Regularly  56.0
# 14             ACTIVE              Regularly  29.0
# 15             ACTIVE              Regularly  54.0
#
#                                           postal_code
# 4   25fa5ddee9aac01b35208d01736e57942317d756b32ddd...
# 7   8d6f45050876d059c830a0fe63f1a4c022de279bb68ce3...
# 13  b31984b20a8c478de38eaf113c581ff64e63c4242e607b...
# ...

# %%
print_unique_col_values(customers_df)
# Out:
# customer_id : ['00006413d8573cd20ed7128e53b7b13819fe5cfc2d801fe7fc0f26dd8d65a85a'
#  '00007d2de826758b65a93dd24ce629ed66842531df6699338c5570910a014cc2'
#  '00009d946eec3ea54add5ba56d5210ea898def4b46c68570cf0096d962cacc75' ...
#  'ffffaff3905b803d1c7e153a1378a5151e1f34f236ba5451afc7cf3f699c5690'
#  'ffffcf35913a0bee60e8741cb2b4e78b8a98ee5ff2e6a1778d0116cffd259264'
#  'ffffd7744cebcf3aca44ae7049d2a94b87074c3d4ffe38b2236865d949d4df6a']
# FN : [1.]
# Active : [1.]
# club_member_status : ['ACTIVE' 'PRE-CREATE' 'LEFT CLUB']
# fashion_news_frequency : ['Regularly' 'NONE' 'Monthly' 'None']
# age : [52. 32. 56. 29. 54. 49. 41. 27. 30. 40. 31. 68. 20. 44. 53. 25. 17. 55.
#  22. 18. 34. 19. 70. 33. 21. 28. 45. 26. 58. 50. 71. 23. 51. 59. 47. 48.
#  38. 35. 42. 67. 43. 46. 24. 61. 57. 37. 64. 36. 62. 73. 69. 63. 39. 60.
#  65. 66. 82. 16. 72. 75. 78. 76. 74. 79. 77. 80. 84. 81. 85. 83. 98. 87.
#  90. 88. 89. 86. 99. 92. 95. 97. 94. 91.]
# ...

# %%
#Dropping FN and Active columns
customers_df = customers_df.drop(['FN', 'Active'], axis=1)

# %%
customers_df.describe()
# Out:
#                  age
# count  462911.000000
# mean       37.108453
# std        14.892004
# min        16.000000
# 25%        24.000000
# 50%        33.000000
# 75%        50.000000
# max        99.000000

# %%
customers_df.groupby('club_member_status').age.plot(kind='kde')
# Out:
# club_member_status
# ACTIVE        AxesSubplot(0.125,0.125;0.775x0.755)
# LEFT CLUB     AxesSubplot(0.125,0.125;0.775x0.755)
# PRE-CREATE    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: age, dtype: object

# %%
axarr = customers_df.age.hist()
axarr.set_xlabel("Age")
# Out:
# Text(0.5, 0, 'Age')

# %%
customers_df.groupby('club_member_status').age.hist()
# Out:
# club_member_status
# ACTIVE        AxesSubplot(0.125,0.125;0.775x0.755)
# LEFT CLUB     AxesSubplot(0.125,0.125;0.775x0.755)
# PRE-CREATE    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: age, dtype: object

# %%
articles_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105542 entries, 0 to 105541
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   article_id                    105542 non-null  int64
#  1   product_code                  105542 non-null  int64
#  2   prod_name                     105542 non-null  object
#  3   product_type_no               105542 non-null  int64
#  4   product_type_name             105542 non-null  object
#  5   product_group_name            105542 non-null  object
#  6   graphical_appearance_no       105542 non-null  int64
#  7   graphical_appearance_name     105542 non-null  object
#  8   colour_group_code             105542 non-null  int64
#  9   colour_group_name             105542 non-null  object
#  10  perceived_colour_value_id     105542 non-null  int64
#  11  perceived_colour_value_name   105542 non-null  object
# ...

# %%
#Dropping null values
articles_df =articles_df.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

# %%
articles_df.describe()
# Out:
#          article_id   product_code  product_type_no  graphical_appearance_no  \
# count  1.051260e+05  105126.000000    105126.000000             1.051260e+05
# mean   6.987962e+08  698796.221430       234.954902             1.009513e+06
# std    1.284961e+08  128496.084636        74.989382             2.245787e+04
# min    1.087750e+08  108775.000000        -1.000000            -1.000000e+00
# 25%    6.173330e+08  617333.000000       252.000000             1.010008e+06
# 50%    7.027780e+08  702778.000000       259.000000             1.010016e+06
# 75%    7.969778e+08  796977.750000       272.000000             1.010016e+06
# max    9.594610e+08  959461.000000       762.000000             1.010029e+06
#
#        colour_group_code  perceived_colour_value_id  \
# count      105126.000000              105126.000000
# mean           32.237524                   3.205392
# std            28.084273                   1.564296
# min            -1.000000                  -1.000000
# ...

# %%
articles_df.describe(include=object)
# Out:
#               prod_name product_type_name  product_group_name  \
# count            105126            105126              105126
# unique            45712               131                  19
# top     Dragonfly dress          Trousers  Garment Upper body
# freq                 98             11140               42593
#
#        graphical_appearance_name colour_group_name  \
# count                     105126            105126
# unique                        30                50
# top                        Solid             Black
# freq                       49548             22559
#
#        perceived_colour_value_name perceived_colour_master_name  \
# count                       105126                       105126
# unique                           8                           20
# top                           Dark                        Black
# freq                         42496                        22475
#
#        department_name index_code  index_name index_group_name  \
# ...

# %% [markdown]
# Save process files

# %%
articles_df.to_csv("/content/gdrive/MyDrive/Dataset/MIT805/output/product-meta-data.csv")

# %%
customers_df.to_csv("/content/gdrive/MyDrive/Dataset/MIT805/output/customer-meta-data.csv")

# %%
transactions_df.to_csv("/content/gdrive/MyDrive/Dataset/MIT805/output/transaction-history.csv")
